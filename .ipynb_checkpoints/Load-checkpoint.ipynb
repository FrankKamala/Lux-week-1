# %%
import pandas as pd
import requests
url = 'https://randomuser.me/api?results=100&gender=male'
r = requests.get(url)
json = r.json()
json.keys()
# Out:
# dict_keys(['results', 'info'])

# %%
json['results']
# Out:
# [{'gender': 'male',
#   'name': {'title': 'Mr', 'first': 'Lance', 'last': 'Hale'},
#   'location': {'street': {'number': 2056, 'name': 'Wheeler Ridge Dr'},
#    'city': 'Altoona',
#    'state': 'New Mexico',
#    'country': 'United States',
#    'postcode': 79792,
#    'coordinates': {'latitude': '86.9835', 'longitude': '-3.7178'},
#    'timezone': {'offset': '+6:00', 'description': 'Almaty, Dhaka, Colombo'}},
#   'email': 'lance.hale@example.com',
#   'login': {'uuid': '95c3f09c-ab3c-4e8e-a073-0a9245ffcb73',
#    'username': 'heavyduck106',
#    'password': '1021',
#    'salt': 'NToW4F4k',
#    'md5': '8d18ebbad2ddfc93c01aa87a8ec8c61c',
#    'sha1': '0f2c72f561c642814e6bde376873cab459502d3c',
#    'sha256': 'a9191c5f169887ec24c219529bf2271feac1e01d31e91ff61b930ec0ae4ab1bc'},
#   'dob': {'date': '1983-02-20T23:25:53.533Z', 'age': 39},
#   'registered': {'date': '2014-01-28T01:34:54.209Z', 'age': 9},
#   'phone': '(439) 976-4135',
#   'cell': '(584) 448-5537',
# ...

# %%
df=pd.DataFrame(json['results'])
df
# Out:
#    gender                                               name  \
# 0    male  {'title': 'Mr', 'first': 'Goricvit', 'last': '...
# 1    male  {'title': 'Mr', 'first': 'Emiliano', 'last': '...
# 2    male  {'title': 'Mr', 'first': 'Tyler', 'last': 'Rey...
# 3    male  {'title': 'Mr', 'first': 'Alex', 'last': 'Dupu...
# 4    male  {'title': 'Mr', 'first': 'Branislav', 'last': ...
# ..    ...                                                ...
# 95   male  {'title': 'Mr', 'first': 'Uriel', 'last': 'Lim...
# 96   male  {'title': 'Mr', 'first': 'Shivansh', 'last': '...
# 97   male  {'title': 'Mr', 'first': 'Malvin', 'last': 'Sl...
# 98   male   {'title': 'Mr', 'first': 'Arin', 'last': 'Kaur'}
# 99   male  {'title': 'Mr', 'first': 'Lucas', 'last': 'Ort...
#
#                                              location  \
# 0   {'street': {'number': 2937, 'name': 'Velika Ok...
# 1   {'street': {'number': 1021, 'name': 'Corredor ...
# 2   {'street': {'number': 7198, 'name': 'New Road'...
# ...
